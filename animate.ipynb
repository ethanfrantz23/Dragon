# %%
openjaw = [round(a, 1) for a in (0 - i * 0.5 for i in range(27*2))]
angles = openjaw + openjaw[::-1]
len(angles)
# Out:
# 108

# %%
import json

with open('files/angles.json', 'w') as f:
    json.dump(angles, f)

# %%
2/542
# Out:
# 0.0036900369003690036
